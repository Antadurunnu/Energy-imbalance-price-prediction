# %%
from apymb import *

# %%
# Main data packages. 
import numpy as np
import pandas as pd
import datetime

# Data Viz. 
import statsmodels.formula.api as smf
from statsmodels.tsa.seasonal import seasonal_decompose
from scipy.ndimage import gaussian_filter


import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df_1= pd.read_csv("data/data_processed/EQ_epex_da_last_prognosis_count.csv")

# %%
df_1['timestamp']=df_1['timestamp'].astype('datetime64')

# %%
df_2= pd.read_csv("data/data_processed/regelleistung_aggr_results_simplified_df.csv")

# %%
df_2['date_start']=df_2['date_start'].astype('datetime64')

# %%
df_3 = pd.read_csv("data/data_processed/regelleistung_demand_processed.csv")

# %%
df_3['date_start']=df_3['date_start'].astype('datetime64')

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 681 entries, 0 to 680
# Data columns (total 49 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   date_start                            681 non-null    datetime64[ns]
#  1   NEG_00_04MRL_total_demand_mw          681 non-null    float64
#  2   NEG_00_04MRL_germany_block_demand_mw  681 non-null    float64
#  3   NEG_00_04SRL_total_demand_mw          681 non-null    float64
#  4   NEG_00_04SRL_germany_block_demand_mw  681 non-null    float64
#  5   NEG_04_08MRL_total_demand_mw          681 non-null    float64
#  6   NEG_04_08MRL_germany_block_demand_mw  681 non-null    float64
#  7   NEG_04_08SRL_total_demand_mw          681 non-null    float64
#  8   NEG_04_08SRL_germany_block_demand_mw  681 non-null    float64
#  9   NEG_08_12MRL_total_demand_mw          681 non-null    float64
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 674 entries, 0 to 673
# Columns: 313 entries, date_start to POS_20_24SRL_germany_import_export_mw
# dtypes: datetime64[ns](1), float64(312)
# memory usage: 1.6 MB

# %%
df_input = align(df_1,df_2, df_3)

# %%
df_input.to_csv("data/data_processed/df_combined.csv", index=True)

# %%
df_input.describe()
# Out:
#         1_prognosis  2_NEG_00_04MRL_total_min_capacity_price_eur_mw  \
# count  19369.000000                                    19369.000000
# mean      35.124564                                        0.029945
# std       16.378353                                        0.291216
# min     -197.710000                                        0.000000
# 25%       25.980000                                        0.000000
# 50%       35.840000                                        0.000000
# 75%       44.900000                                        0.000000
# max      134.330000                                        4.997000
#
#        2_NEG_00_04MRL_total_average_capacity_price_eur_mw  \
# count                                       19369.000000
# mean                                            7.781833
# std                                            15.378731
# min                                             0.000000
# 25%                                             0.000000
# ...
